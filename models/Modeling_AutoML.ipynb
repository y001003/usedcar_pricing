# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기
names=['model','option','year','odometer','fuel','price']
avante = pd.read_csv('./data/avante_df.csv')
genesis = pd.read_csv('./data/genesis_df.csv')
grandure = pd.read_csv('./data/grandure_df.csv')
sonata = pd.read_csv('./data/sonata_df.csv')
santafe = pd.read_csv('./data/santafe_df.csv')

avante = pd.DataFrame(data=avante).reset_index().iloc[:,2:]
genesis = pd.DataFrame(genesis).reset_index().iloc[:,2:]
grandure = pd.DataFrame(grandure).reset_index().iloc[:,2:]
sonata = pd.DataFrame(sonata).reset_index().iloc[:,2:]
santafe = pd.DataFrame(santafe).reset_index().iloc[:,2:]
avante
# Out:
#         model           option          year  odometer fuel  price     car
# 0      아반떼 AD   1.6 GDI 밸류 플러스        18/02식     46374  가솔린   1300  avante
# 1     더 뉴 아반떼  1.6 GDi 스마트 기본형        14/05식     78255  가솔린    880  avante
# 2      아반떼 AD      1.6 GDI 스타일  16/12식(17년형)     60873  가솔린   1199  avante
# 3      아반떼 AD   1.6 GDI 밸류 플러스        18/02식     46374  가솔린   1300  avante
# 4      아반떼 MD      M16 GDI 럭셔리        12/08식     93310  가솔린    660  avante
# ...       ...              ...           ...       ...  ...    ...     ...
# 5675   아반떼 HD  1.6 VVT S16 럭셔리        10/10식     59500  가솔린    490  avante
# 5676   아반떼 HD  1.6 VVT S16 럭셔리        09/04식     96790  가솔린    470  avante
# 5677   아반떼 MD      M16 GDI 에비뉴  13/08식(14년형)    119307  가솔린    480  avante
# 5678  더 뉴 아반떼   1.6 VGT 모던 기본형  14/10식(15년형)    149123   디젤    550  avante
# 5679   아반떼 HD  1.6 VVT S16 럭셔리        10/05식    130164  가솔린    280  avante
#
# [5680 rows x 7 columns]

# %%
avante.info(),genesis.info(),grandure.info(),sonata.info(),santafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5680 entries, 0 to 5679
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   model     5680 non-null   object
#  1   option    5680 non-null   object
#  2   year      5680 non-null   object
#  3   odometer  5680 non-null   int64
#  4   fuel      5680 non-null   object
#  5   price     5680 non-null   int64
#  6   car       5680 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 310.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6444 entries, 0 to 6443
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   model     6444 non-null   object
#  1   option    6444 non-null   object
#  2   year      6444 non-null   object
#  3   odometer  6444 non-null   int64
#  4   fuel      6444 non-null   object
#  5   price     6444 non-null   int64
#  6   car       6444 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 352.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9172 entries, 0 to 9171
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   model     9172 non-null   object
#  1   option    9172 non-null   object
#  2   year      9172 non-null   object
#  3   odometer  9172 non-null   int64
#  4   fuel      9172 non-null   object
#  5   price     9172 non-null   int64
#  6   car       9172 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 501.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5474 entries, 0 to 5473
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   model     5474 non-null   object
#  1   option    5474 non-null   object
#  2   year      5474 non-null   object
#  3   odometer  5474 non-null   int64
#  4   fuel      5474 non-null   object
#  5   price     5474 non-null   int64
#  6   car       5474 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 299.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3814 entries, 0 to 3813
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   model     3814 non-null   object
#  1   option    3814 non-null   object
#  2   year      3814 non-null   object
#  3   odometer  3814 non-null   int64
#  4   fuel      3814 non-null   object
#  5   price     3814 non-null   int64
#  6   car       3814 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 208.7+ KB
# (None, None, None, None, None)

# %%
dfs=[avante,genesis,grandure,sonata,santafe]
# dfs_names=['avante_df','genesis_df','grandure_df','sonata_df','santafe_df']
train = pd.concat(dfs,axis=0)
train
# Out:
#         model                    option          year  odometer fuel  price  \
# 0      아반떼 AD            1.6 GDI 밸류 플러스        18/02식     46374  가솔린   1300
# 1     더 뉴 아반떼           1.6 GDi 스마트 기본형        14/05식     78255  가솔린    880
# 2      아반떼 AD               1.6 GDI 스타일  16/12식(17년형)     60873  가솔린   1199
# 3      아반떼 AD            1.6 GDI 밸류 플러스        18/02식     46374  가솔린   1300
# 4      아반떼 MD               M16 GDI 럭셔리        12/08식     93310  가솔린    660
# ...       ...                       ...           ...       ...  ...    ...
# 3809   싼타페 DM  디젤(e-VGT) 2.0 2WD 익스클루시브  14/07식(15년형)     78199   디젤   1470
# 3810   싼타페 TM         디젤 2.0 2WD 익스클루시브  18/02식(19년형)     40533   디젤   2580
# 3811   싼타페 DM  디젤(e-VGT) 2.0 2WD 익스클루시브  12/09식(13년형)    133200   디젤   1350
# 3812   싼타페 DM    디젤(e-VGT) 2.0 2WD 프리미엄  14/03식(15년형)     83132   디젤   1660
# 3813   싼타페 CM       2WD(2.2VGT) MLX 고급형  06/12식(07년형)    172197   디젤    330
#
#           car
# 0      avante
# 1      avante
# 2      avante
# 3      avante
# 4      avante
# ...       ...
# 3809  santafe
# 3810  santafe
# 3811  santafe
# 3812  santafe
# 3813  santafe
#
# [30584 rows x 7 columns]

# %%
import jinja2
from pycaret.regression import *
# X_train, y_train
reg_test_1 = setup(data=train,
                   target='price',
                   train_size= 0.85,
                #    test_data=X_val,
                   use_gpu =True,
                   normalize=True,
                   normalize_method ='minmax',
#                    remove_perfect_collinearity=False,
                   fold=10
                   )
# Out:
# <style type="text/css">
# #T_2ff35_row8_col1, #T_2ff35_row14_col1, #T_2ff35_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2ff35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ff35_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2ff35_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ff35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ff35_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2ff35_row0_col1" class="data row0 col1" >270</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ff35_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2ff35_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ff35_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2ff35_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ff35_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_2ff35_row3_col1" class="data row3 col1" >(129548, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ff35_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_2ff35_row4_col1" class="data row4 col1" >(110115, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ff35_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_2ff35_row5_col1" class="data row5 col1" >(19433, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2ff35_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_2ff35_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2ff35_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_2ff35_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2ff35_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2ff35_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2ff35_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2ff35_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2ff35_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2ff35_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2ff35_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2ff35_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2ff35_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_2ff35_row12_col1" class="data row12 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2ff35_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_2ff35_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2ff35_row14_col0" class="data row14 col0" >Normalize</td>
#       <td id="T_2ff35_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2ff35_row15_col0" class="data row15 col0" >Normalize method</td>
#       <td id="T_2ff35_row15_col1" class="data row15 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2ff35_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_2ff35_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2ff35_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_2ff35_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2ff35_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_2ff35_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2ff35_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_2ff35_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2ff35_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_2ff35_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2ff35_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_2ff35_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2ff35_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2ff35_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_2ff35_row22_col1" class="data row22 col1" >14a3</td>
#     </tr>
#   </tbody>
# </table>
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1
# [LightGBM] [Fatal] GPU Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_GPU=1
# [LightGBM] [Fatal] CUDA Tree Learner was not enabled in this build.
# Please recompile with CMake option -DUSE_CUDA=1

# %%
best= compare_models(sort='mse',n_select=5)

# %%
top5 = [rank for rank in best]
top5_tune = [tune_model(i) for i in top5]

# %%
blended = blend_models(estimator_list = best,
                       fold = 5,
#                        method = 'soft',
                       optimize='mae',
                       )

# %%
final_model = finalize_model(blended)

# %%
save_model(final_model, 'final_AutoML_model')

# %%
files.download('final_blended.pkl')
